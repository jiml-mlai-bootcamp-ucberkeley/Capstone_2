# %%
from warnings import filterwarnings 
filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import KMeans

# %% [markdown]
# #### Read the outliers file and add a feature "prev_sold_year"

# %%
realtor_data_df = pd.read_csv('outliers.csv')
realtor_data_df["prev_sold_year"] = pd.to_datetime(realtor_data_df["prev_sold_date"], format='%Y-%m-%d').dt.year

# %%
for_sale_df = realtor_data_df

# %% [markdown]
# #### Create a feature that will append '0' to the zipcode feature

# %%
for_sale_df["zip_code_str"] = '0'+ for_sale_df["zip_code"].apply(int).apply(str)
for_sale_df.head()
# Out:
#    Unnamed: 0  bed  bath  acre_lot  zip_code  house_size prev_sold_date  \
# 0           1  3.0   2.0      2.02   12521.0      1600.0     2021-11-24
# 1           2  4.0   2.0      0.24   12521.0      1239.0     2018-02-01
# 2           7  3.0   2.0      1.20   12546.0      1350.0     2018-08-31
# 3          16  3.0   2.0      5.01   12060.0      2504.0     2020-11-09
# 4          27  3.0   2.0     19.70   12529.0      1200.0     2021-01-20
#
#       price  prev_sold_year zip_code_str
# 0  425000.0            2021       012521
# 1  225000.0            2018       012521
# 2  375000.0            2018       012546
# 3  435000.0            2020       012060
# 4  625000.0            2021       012529

# %% [markdown]
# #### Get the unique zipcodes in the dataframe

# %%
zipcodes = for_sale_df["zip_code"]
len(zipcodes.unique())
# Out:
# 1145

# %% [markdown]
# #### Read the file with Latitude and Longitude, rename the features

# %%
# Because of its size this dataset is not saved in the code repo for this project.
# It can be downloaded and saved in the same path to make this Notebook run.
zip_lon_lat = pd.read_csv('../../../zip_lat_long.csv')
zip_lon_lat.rename(columns={"ZIP":"zip_code", "LAT":"latitude", "LNG":"longitude"},inplace=True)
zip_lon_lat.head()
# Out:
#    zip_code   latitude  longitude
# 0       601  18.180555 -66.749961
# 1       602  18.361945 -67.175597
# 2       603  18.455183 -67.119887
# 3       606  18.158345 -66.932911
# 4       610  18.295366 -67.125135

# %% [markdown]
# #### Find matching zipcodes that were found in the dataset

# %%
find_zipcodes_df = zip_lon_lat[zip_lon_lat["zip_code"].isin(zipcodes.unique())]
find_zipcodes_df["zip_code_str"] = "0"+find_zipcodes_df["zip_code"].apply(str)
find_zipcodes_df.head()
# Out:
#       zip_code   latitude  longitude zip_code_str
# 2569     10001  40.750633 -73.997177       010001
# 2570     10002  40.715775 -73.986212       010002
# 2571     10003  40.731829 -73.989181       010003
# 2572     10004  40.688630 -74.018244       010004
# 2573     10005  40.706027 -74.008835       010005

# %% [markdown]
# #### Merge the dataset with the Latitude and Longitude data

# %%
merge_df = for_sale_df.merge(find_zipcodes_df, how='outer', on='zip_code_str')

merge_df.rename(columns={"zip_code_x":"zip_code"},inplace=True)
merge_df.drop(columns=["zip_code_y"],inplace=True)

# %% [markdown]
# #### Display the records that didn't match up

# %%
merge_df[merge_df["latitude"].isna()]
# Out:
#       Unnamed: 0  bed  bath  acre_lot  zip_code  house_size prev_sold_date  \
# 2252        2805  3.0   2.0      0.05   10129.0      1200.0     2019-08-02
# 3903        3510  1.0   1.0      0.05   11249.0      1200.0     2018-07-20
# 3904        4895  4.0   2.0      0.05   11249.0      1200.0     2019-11-06
# 3905       10988  1.0   2.0      0.05   11249.0       905.0     2017-01-05
# 3906       12594  2.0   1.0      0.05   11249.0      1200.0     2018-12-12
# 3907       12597  1.0   1.0      0.05   11249.0       816.0     2017-01-03
# 3908       16892  1.0   2.0      0.05   11249.0       848.0     2016-12-29
# 3909       16896  2.0   2.0      0.05   11249.0      1336.0     2017-06-06
# 3910       17145  2.0   2.0      0.05   11249.0      1129.0     2019-05-30
# 3911       23679  1.0   1.0      0.05   11249.0       688.0     2017-12-22
# 3912       25543  1.0   1.0      0.05   11249.0       787.0     2017-12-18
# 4334        5126  1.0   2.0      0.05   11243.0      1152.0     2017-06-22
# 4335       16900  3.0   1.0      0.05   11243.0       489.0     2016-11-23
# 6075       14613  3.0   2.0      0.61   10982.0      1916.0     2021-12-31
#
#           price  prev_sold_year zip_code_str  latitude  longitude
# 2252  2650000.0            2019       010129       NaN        NaN
# 3903   895000.0            2018       011249       NaN        NaN
# 3904  2900000.0            2019       011249       NaN        NaN
# 3905  1225000.0            2017       011249       NaN        NaN
# 3906  1400000.0            2018       011249       NaN        NaN
# 3907  1050000.0            2017       011249       NaN        NaN
# 3908   950000.0            2016       011249       NaN        NaN
# 3909  1450000.0            2017       011249       NaN        NaN
# 3910  1500000.0            2019       011249       NaN        NaN
# 3911  1240000.0            2017       011249       NaN        NaN
# 3912  1100000.0            2017       011249       NaN        NaN
# 4334  1450000.0            2017       011243       NaN        NaN
# 4335   499000.0            2016       011243       NaN        NaN
# 6075   800000.0            2021       010982       NaN        NaN

# %%
# "08218","39.1386785","-74.856442"

# %%
# "08239","39.1979584","-74.6577965"

# %%
# "08245","39.1778125","-74.8300693"

# %% [markdown]
# #### Drop the records that didn't match up

# %%
merge_df.dropna(subset=['latitude'], inplace=True)

# %%
merge_df.head()
# Out:
#    Unnamed: 0  bed  bath  acre_lot  zip_code  house_size prev_sold_date  \
# 0           1  3.0   2.0      2.02   12521.0      1600.0     2021-11-24
# 1           2  4.0   2.0      0.24   12521.0      1239.0     2018-02-01
# 2         387  3.0   3.0      0.09   12521.0      1320.0     2020-02-28
# 3         696  3.0   3.0      5.00   12521.0      2517.0     2017-05-30
# 4           7  3.0   2.0      1.20   12546.0      1350.0     2018-08-31
#
#       price  prev_sold_year zip_code_str   latitude  longitude
# 0  425000.0            2021       012521  42.171335 -73.650487
# 1  225000.0            2018       012521  42.171335 -73.650487
# 2  995000.0            2020       012521  42.171335 -73.650487
# 3  895000.0            2017       012521  42.171335 -73.650487
# 4  375000.0            2018       012546  41.948000 -73.523349

# %% [markdown]
# #### Use KMeans to cluster latitude and longitude into counties

# %%
numberofcounties = 62
kmeans = KMeans( init="random", n_clusters=21,random_state=0)
latlong = merge_df[["latitude","longitude"]]
kmeans.fit(latlong)
y_kmeans = kmeans.predict(latlong)

# %% [markdown]
# #### Plot the counties

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plt.scatter(merge_df["longitude"], merge_df["latitude"], c=y_kmeans, s=50, cmap='viridis')

# %% [markdown]
# #### Add county to the dataset going forward

# %%
merge_df["county"] = y_kmeans

# %%
merge_df.head()
# Out:
#    Unnamed: 0  bed  bath  acre_lot  zip_code  house_size prev_sold_date  \
# 0           1  3.0   2.0      2.02   12521.0      1600.0     2021-11-24
# 1           2  4.0   2.0      0.24   12521.0      1239.0     2018-02-01
# 2         387  3.0   3.0      0.09   12521.0      1320.0     2020-02-28
# 3         696  3.0   3.0      5.00   12521.0      2517.0     2017-05-30
# 4           7  3.0   2.0      1.20   12546.0      1350.0     2018-08-31
#
#       price  prev_sold_year zip_code_str   latitude  longitude  county
# 0  425000.0            2021       012521  42.171335 -73.650487      19
# 1  225000.0            2018       012521  42.171335 -73.650487      19
# 2  995000.0            2020       012521  42.171335 -73.650487      19
# 3  895000.0            2017       012521  42.171335 -73.650487      19
# 4  375000.0            2018       012546  41.948000 -73.523349      19

# %% [markdown]
# #### Save the records to a csv file

# %%
merge_df.to_csv("geocoded.csv")
