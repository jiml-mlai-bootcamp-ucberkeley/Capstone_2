# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.561798842',
  '0.697087706',
  '0.765378203',
  '0.740545286'],
 'mae score': ['0.548722', '0.277870', '0.228738', '0.231710'],
 'mse score': ['0.569753', '0.287812', '0.222997', '0.246532'],
 'r2 score': ['0.400355', '0.697087', '0.765304', '0.740533'],
 'mean fit time': [0.0986668586730957,
  0.5893467426300049,
  0.5267816543579101,
  4.1320109367370605]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.691274677', '0.398744433', '0.571486328'],
 'mae score': ['0.270628', '0.399311', '0.297668'],
 'mse score': ['0.293423', '0.571409', '0.407200'],
 'r2 score': ['0.691182', '0.398612', '0.571436'],
 'mean fit time': [0.01217637062072754,
  0.012051534652709962,
  0.01787147521972656]}
)

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.687526427', '0.554496400'],
 'mae score': ['0.270216', '0.317984'],
 'mse score': ['0.296922', '0.423491'],
 'r2 score': ['0.687500', '0.554290'],
 'mean fit time': [0.0017019748687744141, 0.0036703109741210937]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.265384688',
  '0.265384794',
  '0.161209986',
  '0.265389263'],
 'mae score': ['442,512.946892',
  '442,512.634874',
  '468,320.408379',
  '442,513.605785'],
 'mse score': ['573,027,063,519.499268',
  '573,026,981,159.719604',
  '654,428,340,309.117065',
  '573,021,648,485.772217'],
 'r2 score': ['0.265179', '0.265179', '0.160794', '0.265186'],
 'mean fit time': [0.39382190704345704,
  0.012598800659179687,
  0.008282327651977539,
  0.004770231246948242]})

# %%
linear_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.265384688',
  '0.265389158',
  '0.161209979',
  '0.265389158',
  '0.265384688'],
 'mae score': ['0.488456', '0.488457', '0.516943', '0.488457', '0.488456'],
 'mse score': ['0.698190', '0.698184', '0.797371', '0.698184', '0.698190'],
 'r2 score': ['0.265179', '0.265185', '0.160794', '0.265185', '0.265179'],
 'mean fit time': [0.0007178783416748047,
  0.004521942138671875,
  0.004090118408203125,
  0.002675294876098633,
  0.005324792861938476]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.265384688',
  '0.265393158',
  '0.161211213',
  '0.265393158'],
 'mae score': ['0.488456', '0.488444', '0.516937', '0.488444'],
 'mse score': ['0.698190', '0.698180', '0.797370', '0.698180'],
 'r2 score': ['0.265179', '0.265189', '0.160795', '0.265189'],
 'mean fit time': [0.0,
  0.0016269683837890625,
  0.001647806167602539,
  0.0031264781951904296]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.561798842  0.548722  0.569753
# 1       Gradient Boosting              0.697087706  0.277870  0.287812
# 2  Hist Gradient Boosting              0.765378203  0.228738  0.222997
# 3           Random Forest              0.740545286  0.231710  0.246532
#
#    r2 score  mean fit time
# 0  0.400355       0.098667
# 1  0.697087       0.589347
# 2  0.765304       0.526782
# 3  0.740533       4.132011

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params              0.691274677  0.270628  0.293423
# 1  Recursive Feature Elimination              0.398744433  0.399311  0.571409
# 2    Sequential Feature Selector              0.571486328  0.297668  0.407200
#
#    r2 score  mean fit time
# 0  0.691182       0.012176
# 1  0.398612       0.012052
# 2  0.571436       0.017871

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.687526427  0.270216  0.296922
# 1  Sequential Feature Selector              0.554496400  0.317984  0.423491
#
#    r2 score  mean fit time
# 0  0.687500       0.001702
# 1  0.554290       0.003670

# %%
lasso_df
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.265384688  442,512.946892
# 1              Select From Model              0.265384794  442,512.634874
# 2    Sequential Feature Selector              0.161209986  468,320.408379
# 3  Recursive Feature Elimination              0.265389263  442,513.605785
#
#                 mse score  r2 score  mean fit time
# 0  573,027,063,519.499268  0.265179       0.393822
# 1  573,026,981,159.719604  0.265179       0.012599
# 2  654,428,340,309.117065  0.160794       0.008282
# 3  573,021,648,485.772217  0.265186       0.004770

# %%
linear_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.265384688  0.488456  0.698190
# 1              Select From Model              0.265389158  0.488457  0.698184
# 2    Sequential Feature Selector              0.161209979  0.516943  0.797371
# 3  Recursive Feature Elimination              0.265389158  0.488457  0.698184
# 4             PolynomialFeatures              0.265384688  0.488456  0.698190
#
#    r2 score  mean fit time
# 0  0.265179       0.000718
# 1  0.265185       0.004522
# 2  0.160794       0.004090
# 3  0.265185       0.002675
# 4  0.265179       0.005325

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.265384688  0.488456  0.698190
# 1              Select From Model              0.265393158  0.488444  0.698180
# 2    Sequential Feature Selector              0.161211213  0.516937  0.797370
# 3  Recursive Feature Elimination              0.265393158  0.488444  0.698180
#
#    r2 score  mean fit time
# 0  0.265179       0.000000
# 1  0.265189       0.001627
# 2  0.160795       0.001648
# 3  0.265189       0.003126
