# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.726025110',
  '0.794287996',
  '0.721259049',
  '0.791359329'],
 'mae score': ['0.354560', '0.316121', '0.344220', '0.320648'],
 'mse score': ['0.244248', '0.175517', '0.237900', '0.178123'],
 'r2 score': ['0.713730', '0.794285', '0.721169', '0.791231'],
 'mean fit time': [0.006557559967041016,
  0.023104381561279298,
  0.08960494995117188,
  0.07371926307678223]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.765909580', '0.750864075', '0.750864075'],
 'mae score': ['0.332906', '0.352803', '0.352803'],
 'mse score': ['0.207461', '0.212569', '0.212569'],
 'r2 score': ['0.756846', '0.750859', '0.750859'],
 'mean fit time': [0.003397083282470703,
  0.0015832901000976563,
  0.0015866279602050782]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.657323824', '0.764517945'],
 'mae score': ['0.385727', '0.351551'],
 'mse score': ['0.297994', '0.221800'],
 'r2 score': ['0.650736', '0.740040'],
 'mean fit time': [0.0, 0.0]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.681201943',
  '0.681202001',
  '0.681202001',
  '0.681202001'],
 'mae score': ['721,693.950774',
  '721,693.787313',
  '721,693.787313',
  '721,693.787313'],
 'mse score': ['701,294,499,278.507446',
  '701,294,340,426.075317',
  '701,294,340,426.075317',
  '701,294,340,426.075317'],
 'r2 score': ['0.667712', '0.667712', '0.667712', '0.667712'],
 'mean fit time': [0.003869295120239258,
  0.0025131702423095703,
  0.002605152130126953,
  0.0018826007843017578]})

# %%
linear_df1 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.677118680',
  '0.073424250',
  '0.675428335',
  '0.644621059',
  '0.770481196'],
 'mae score': ['545,515.163241',
  '919,064.843339',
  '549,676.372055',
  '561,522.047719',
  '424,897.322277'],
 'mse score': ['666,578,337,003.643921',
  '1,911,267,559,867.171631',
  '670,788,729,644.855591',
  '731,955,199,976.608887',
  '474,808,887,090.595581'],
 'r2 score': ['0.675864', '0.070612', '0.673817', '0.644074', '0.769116'],
 'mean fit time': [0.005895757675170898,
  0.003043508529663086,
  0.004717874526977539,
  0.0011296749114990234,
  0.0073337554931640625]}
)

# %%
linear_df2 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.681201943',
  '0.460138427',
  '0.681201943',
  '0.681201943',
  '0.786670024'],
 'mae score': ['721,693.950774',
  '782,308.758369',
  '721,693.950774',
  '721,693.950774',
  '558,827.741205'],
 'mse score': ['701,294,499,278.504639',
  '1,141,804,321,572.385498',
  '701,294,499,278.504639',
  '701,294,499,278.504639',
  '464,664,454,491.537659'],
 'r2 score': ['0.667712', '0.458989', '0.667712', '0.667712', '0.779832'],
 'mean fit time': [0.0011103153228759766,
  0.0,
  0.0026506900787353514,
  0.0,
  0.0031843662261962892]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.681201943',
  '0.650200104',
  '0.681264616',
  '0.681264616'],
 'mae score': ['0.458867', '0.490030', '0.457678', '0.457678'],
 'mse score': ['0.283510', '0.313843', '0.283273', '0.283273'],
 'r2 score': ['0.667712', '0.632160', '0.667990', '0.667990'],
 'mean fit time': [0.001165008544921875,
  0.0016900062561035155,
  0.0001148223876953125,
  0.0]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.726025110  0.354560  0.244248
# 1       Gradient Boosting              0.794287996  0.316121  0.175517
# 2  Hist Gradient Boosting              0.721259049  0.344220  0.237900
# 3           Random Forest              0.791359329  0.320648  0.178123
#
#    r2 score  mean fit time
# 0  0.713730       0.006558
# 1  0.794285       0.023104
# 2  0.721169       0.089605
# 3  0.791231       0.073719

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params              0.765909580  0.332906  0.207461
# 1  Recursive Feature Elimination              0.750864075  0.352803  0.212569
# 2    Sequential Feature Selector              0.750864075  0.352803  0.212569
#
#    r2 score  mean fit time
# 0  0.756846       0.003397
# 1  0.750859       0.001583
# 2  0.750859       0.001587

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.657323824  0.385727  0.297994
# 1  Sequential Feature Selector              0.764517945  0.351551  0.221800
#
#    r2 score  mean fit time
# 0  0.650736            0.0
# 1  0.740040            0.0

# %%
lasso_df
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.681201943  721,693.950774
# 1              Select From Model              0.681202001  721,693.787313
# 2    Sequential Feature Selector              0.681202001  721,693.787313
# 3  Recursive Feature Elimination              0.681202001  721,693.787313
#
#                 mse score  r2 score  mean fit time
# 0  701,294,499,278.507446  0.667712       0.003869
# 1  701,294,340,426.075317  0.667712       0.002513
# 2  701,294,340,426.075317  0.667712       0.002605
# 3  701,294,340,426.075317  0.667712       0.001883

# %%
linear_df1
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.677118680  545,515.163241
# 1              Select From Model              0.073424250  919,064.843339
# 2    Sequential Feature Selector              0.675428335  549,676.372055
# 3  Recursive Feature Elimination              0.644621059  561,522.047719
# 4             PolynomialFeatures              0.770481196  424,897.322277
#
#                   mse score  r2 score  mean fit time
# 0    666,578,337,003.643921  0.675864       0.005896
# 1  1,911,267,559,867.171631  0.070612       0.003044
# 2    670,788,729,644.855591  0.673817       0.004718
# 3    731,955,199,976.608887  0.644074       0.001130
# 4    474,808,887,090.595581  0.769116       0.007334

# %%
linear_df2
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.681201943  721,693.950774
# 1              Select From Model              0.460138427  782,308.758369
# 2    Sequential Feature Selector              0.681201943  721,693.950774
# 3  Recursive Feature Elimination              0.681201943  721,693.950774
# 4             PolynomialFeatures              0.786670024  558,827.741205
#
#                   mse score  r2 score  mean fit time
# 0    701,294,499,278.504639  0.667712       0.001110
# 1  1,141,804,321,572.385498  0.458989       0.000000
# 2    701,294,499,278.504639  0.667712       0.002651
# 3    701,294,499,278.504639  0.667712       0.000000
# 4    464,664,454,491.537659  0.779832       0.003184

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.681201943  0.458867  0.283510
# 1              Select From Model              0.650200104  0.490030  0.313843
# 2    Sequential Feature Selector              0.681264616  0.457678  0.283273
# 3  Recursive Feature Elimination              0.681264616  0.457678  0.283273
#
#    r2 score  mean fit time
# 0  0.667712       0.001165
# 1  0.632160       0.001690
# 2  0.667990       0.000115
# 3  0.667990       0.000000
