# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.726025110',
  '0.794287996',
  '0.721259049',
  '0.791359329'],
 'mae score': ['0.354560', '0.316121', '0.344220', '0.320648'],
 'mse score': ['0.244248', '0.175517', '0.237900', '0.178123'],
 'r2 score': ['0.713730', '0.794285', '0.721169', '0.791231'],
 'mean fit time': [0.006557559967041016,
  0.023104381561279298,
  0.08960494995117188,
  0.07371926307678223]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.765909580', '0.750864075', '0.750864075'],
 'mae score': ['0.332906', '0.352803', '0.352803'],
 'mse score': ['0.207461', '0.212569', '0.212569'],
 'r2 score': ['0.756846', '0.750859', '0.750859'],
 'mean fit time': [0.003397083282470703,
  0.0015832901000976563,
  0.0015866279602050782]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.657323824', '0.764517945'],
 'mae score': ['0.385727', '0.351551'],
 'mse score': ['0.297994', '0.221800'],
 'r2 score': ['0.650736', '0.740040'],
 'mean fit time': [0.0, 0.0]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.681201944',
  '0.000000000',
  '0.000000000',
  '0.000000000'],
 'mae score': ['0.458867', '0.723498', '0.723498', '0.723498'],
 'mse score': ['0.283510', '0.857910', '0.857910', '0.857910'],
 'r2 score': ['0.667712', '-0.005513', '-0.005513', '-0.005513'],
 'mean fit time': [0.001850128173828125, 0.003103017807006836, 0.0, 0.0]})

# %%
linear_df1 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.677118680',
  '0.073424250',
  '0.675428335',
  '0.668537568',
  '0.736035980'],
 'mae score': ['0.397891', '0.670352', '0.400926', '0.407476', '0.339771'],
 'mse score': ['0.354621', '1.016799', '0.356861', '0.363957', '0.291127'],
 'r2 score': ['0.675864', '0.070612', '0.673817', '0.667332', '0.733900'],
 'mean fit time': [0.004868221282958984,
  0.0,
  0.003126096725463867,
  0.002770090103149414,
  0.0054966449737548825]})

# %%
linear_df2 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.681202379',
  '-0.000000000',
  '0.681201943',
  '0.650724022',
  '0.786670024'],
 'mae score': ['0.458869', '0.723498', '0.458867', '0.490631', '0.355314'],
 'mse score': ['0.283511', '0.857910', '0.283510', '0.313521', '0.187849'],
 'r2 score': ['0.667711', '-0.005513', '0.667712', '0.632538', '0.779832'],
 'mean fit time': [0.002301931381225586,
  0.002668333053588867,
  0.0014157772064208984,
  0.0021782398223876955,
  0.0034104347229003905]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.681201943',
  '0.650200104',
  '0.681264616',
  '0.681264616'],
 'mae score': ['0.458867', '0.490030', '0.457678', '0.457678'],
 'mse score': ['0.283510', '0.313843', '0.283273', '0.283273'],
 'r2 score': ['0.667712', '0.632160', '0.667990', '0.667990'],
 'mean fit time': [0.001165008544921875,
  0.0016900062561035155,
  0.0001148223876953125,
  0.0]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.726025110  0.354560  0.244248
# 1       Gradient Boosting              0.794287996  0.316121  0.175517
# 2  Hist Gradient Boosting              0.721259049  0.344220  0.237900
# 3           Random Forest              0.791359329  0.320648  0.178123
#
#    r2 score  mean fit time
# 0  0.713730       0.006558
# 1  0.794285       0.023104
# 2  0.721169       0.089605
# 3  0.791231       0.073719

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params              0.765909580  0.332906  0.207461
# 1  Recursive Feature Elimination              0.750864075  0.352803  0.212569
# 2    Sequential Feature Selector              0.750864075  0.352803  0.212569
#
#    r2 score  mean fit time
# 0  0.756846       0.003397
# 1  0.750859       0.001583
# 2  0.750859       0.001587

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.657323824  0.385727  0.297994
# 1  Sequential Feature Selector              0.764517945  0.351551  0.221800
#
#    r2 score  mean fit time
# 0  0.650736            0.0
# 1  0.740040            0.0

# %%
lasso_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.681201944  0.458867  0.283510
# 1              Select From Model              0.000000000  0.723498  0.857910
# 2    Sequential Feature Selector              0.000000000  0.723498  0.857910
# 3  Recursive Feature Elimination              0.000000000  0.723498  0.857910
#
#     r2 score  mean fit time
# 0   0.667712       0.001850
# 1  -0.005513       0.003103
# 2  -0.005513       0.000000
# 3  -0.005513       0.000000

# %%
linear_df1
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.677118680  0.397891  0.354621
# 1              Select From Model              0.073424250  0.670352  1.016799
# 2    Sequential Feature Selector              0.675428335  0.400926  0.356861
# 3  Recursive Feature Elimination              0.668537568  0.407476  0.363957
# 4             PolynomialFeatures              0.736035980  0.339771  0.291127
#
#    r2 score  mean fit time
# 0  0.675864       0.004868
# 1  0.070612       0.000000
# 2  0.673817       0.003126
# 3  0.667332       0.002770
# 4  0.733900       0.005497

# %%
linear_df2
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.681202379  0.458869  0.283511
# 1              Select From Model             -0.000000000  0.723498  0.857910
# 2    Sequential Feature Selector              0.681201943  0.458867  0.283510
# 3  Recursive Feature Elimination              0.650724022  0.490631  0.313521
# 4             PolynomialFeatures              0.786670024  0.355314  0.187849
#
#     r2 score  mean fit time
# 0   0.667711       0.002302
# 1  -0.005513       0.002668
# 2   0.667712       0.001416
# 3   0.632538       0.002178
# 4   0.779832       0.003410

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.681201943  0.458867  0.283510
# 1              Select From Model              0.650200104  0.490030  0.313843
# 2    Sequential Feature Selector              0.681264616  0.457678  0.283273
# 3  Recursive Feature Elimination              0.681264616  0.457678  0.283273
#
#    r2 score  mean fit time
# 0  0.667712       0.001165
# 1  0.632160       0.001690
# 2  0.667990       0.000115
# 3  0.667990       0.000000
