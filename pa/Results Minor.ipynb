# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['-0.863496245',
  '-0.480421294',
  '0.492989717',
  '-0.513024336'],
 'mae score': ['0.709294', '0.519072', '0.421461', '0.559112'],
 'mse score': ['1.160741', '0.804573', '0.280372', '0.841728'],
 'r2 score': ['-1.187364', '-0.516181', '0.471652', '-0.586198'],
 'mean fit time': [0.021404409408569337,
  0.02530961036682129,
  0.09345240592956543,
  0.07411670684814453]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['-0.013938664', '-0.705674416', '-0.705182617'],
 'mae score': ['0.572719', '0.595010', '0.593837'],
 'mse score': ['0.570457', '0.905164', '0.904918'],
 'r2 score': ['-0.075000', '-0.705740', '-0.705276'],
 'mean fit time': [0.0028786659240722656, 0.0007879734039306641, 0.0]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.333670489', '0.021068089'],
 'mae score': ['0.469973', '0.527999'],
 'mse score': ['0.364996', '0.549147'],
 'r2 score': ['0.312182', '-0.034843'],
 'mean fit time': [0.0, 0.0]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.288064381',
  '0.000000000',
  '0.000000000',
  '0.000000000'],
 'mae score': ['0.463259', '0.568824', '0.568824', '0.568824'],
 'mse score': ['0.406576', '0.569027', '0.569027', '0.569027'],
 'r2 score': ['0.233826', '-0.072304', '-0.072304', '-0.072304'],
 'mean fit time': [0.0, 0.0, 0.0027188777923583983, 0.0028518199920654296]})

# %%
linear_df1 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.515137354',
  '0.020107911',
  '0.517130224',
  '0.517130224',
  '0.515137354'],
 'mae score': ['0.456133', '0.700928', '0.455824', '0.455824', '0.456133'],
 'mse score': ['0.438693', '0.913498', '0.436914', '0.436914', '0.438693'],
 'r2 score': ['0.514766', '-0.010412', '0.516734', '0.516734', '0.514766'],
 'mean fit time': [0.0024634361267089843,
  0.0,
  0.0016897201538085937,
  0.0,
  0.004961442947387695]})

# %%
linear_df2 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.288064360',
  '0.000000000',
  '0.288064360',
  '0.288064360',
  '0.288064360'],
 'mae score': ['0.463259', '0.568824', '0.463259', '0.463259', '0.463259'],
 'mse score': ['0.406576', '0.569027', '0.406576', '0.406576', '0.406576'],
 'r2 score': ['0.233826', '-0.072304', '0.233826', '0.233826', '0.233826'],
 'mean fit time': [0.0019035816192626953,
  0.0,
  0.0017754554748535157,
  0.0015728473663330078,
  0.0020860671997070313]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.288064360',
  '0.302486157',
  '0.302486157',
  '0.302486157'],
 'mae score': ['0.463259', '0.461195', '0.461195', '0.461195'],
 'mse score': ['0.406576', '0.398775', '0.398775', '0.398775'],
 'r2 score': ['0.233826', '0.248528', '0.248528', '0.248528'],
 'mean fit time': [0.0010613441467285157,
  0.001784515380859375,
  0.0022294998168945314,
  0.0]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost             -0.863496245  0.709294  1.160741
# 1       Gradient Boosting             -0.480421294  0.519072  0.804573
# 2  Hist Gradient Boosting              0.492989717  0.421461  0.280372
# 3           Random Forest             -0.513024336  0.559112  0.841728
#
#     r2 score  mean fit time
# 0  -1.187364       0.021404
# 1  -0.516181       0.025310
# 2   0.471652       0.093452
# 3  -0.586198       0.074117

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params             -0.013938664  0.572719  0.570457
# 1  Recursive Feature Elimination             -0.705674416  0.595010  0.905164
# 2    Sequential Feature Selector             -0.705182617  0.593837  0.904918
#
#     r2 score  mean fit time
# 0  -0.075000       0.002879
# 1  -0.705740       0.000788
# 2  -0.705276       0.000000

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.333670489  0.469973  0.364996
# 1  Sequential Feature Selector              0.021068089  0.527999  0.549147
#
#     r2 score  mean fit time
# 0   0.312182            0.0
# 1  -0.034843            0.0

# %%
lasso_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.288064381  0.463259  0.406576
# 1              Select From Model              0.000000000  0.568824  0.569027
# 2    Sequential Feature Selector              0.000000000  0.568824  0.569027
# 3  Recursive Feature Elimination              0.000000000  0.568824  0.569027
#
#     r2 score  mean fit time
# 0   0.233826       0.000000
# 1  -0.072304       0.000000
# 2  -0.072304       0.002719
# 3  -0.072304       0.002852

# %%
linear_df1
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.515137354  0.456133  0.438693
# 1              Select From Model              0.020107911  0.700928  0.913498
# 2    Sequential Feature Selector              0.517130224  0.455824  0.436914
# 3  Recursive Feature Elimination              0.517130224  0.455824  0.436914
# 4             PolynomialFeatures              0.515137354  0.456133  0.438693
#
#     r2 score  mean fit time
# 0   0.514766       0.002463
# 1  -0.010412       0.000000
# 2   0.516734       0.001690
# 3   0.516734       0.000000
# 4   0.514766       0.004961

# %%
linear_df2
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.288064360  0.463259  0.406576
# 1              Select From Model              0.000000000  0.568824  0.569027
# 2    Sequential Feature Selector              0.288064360  0.463259  0.406576
# 3  Recursive Feature Elimination              0.288064360  0.463259  0.406576
# 4             PolynomialFeatures              0.288064360  0.463259  0.406576
#
#     r2 score  mean fit time
# 0   0.233826       0.001904
# 1  -0.072304       0.000000
# 2   0.233826       0.001775
# 3   0.233826       0.001573
# 4   0.233826       0.002086

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.288064360  0.463259  0.406576
# 1              Select From Model              0.302486157  0.461195  0.398775
# 2    Sequential Feature Selector              0.302486157  0.461195  0.398775
# 3  Recursive Feature Elimination              0.302486157  0.461195  0.398775
#
#    r2 score  mean fit time
# 0  0.233826       0.001061
# 1  0.248528       0.001785
# 2  0.248528       0.002229
# 3  0.248528       0.000000
