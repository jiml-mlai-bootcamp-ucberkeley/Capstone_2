# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['-0.863496245',
  '-0.480421294',
  '0.492989717',
  '-0.513024336'],
 'mae score': ['0.709294', '0.519072', '0.421461', '0.559112'],
 'mse score': ['1.160741', '0.804573', '0.280372', '0.841728'],
 'r2 score': ['-1.187364', '-0.516181', '0.471652', '-0.586198'],
 'mean fit time': [0.021404409408569337,
  0.02530961036682129,
  0.09345240592956543,
  0.07411670684814453]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['-0.013938664', '-0.705674416', '-0.705182617'],
 'mae score': ['0.572719', '0.595010', '0.593837'],
 'mse score': ['0.570457', '0.905164', '0.904918'],
 'r2 score': ['-0.075000', '-0.705740', '-0.705276'],
 'mean fit time': [0.0028786659240722656, 0.0007879734039306641, 0.0]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.333670489', '0.021068089'],
 'mae score': ['0.469973', '0.527999'],
 'mse score': ['0.364996', '0.549147'],
 'r2 score': ['0.312182', '-0.034843'],
 'mean fit time': [0.0, 0.0]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.288064360',
  '0.288066984',
  '0.288066984',
  '0.288066984'],
 'mae score': ['145,476.615029',
  '145,476.479733',
  '145,476.479733',
  '145,476.479733'],
 'mse score': ['40,094,163,307.607681',
  '40,094,017,861.090286',
  '40,094,017,861.090286',
  '40,094,017,861.090286'],
 'r2 score': ['0.233826', '0.233829', '0.233829', '0.233829'],
 'mean fit time': [0.0006937980651855469, 0.0016909122467041015, 0.0, 0.0]}
)

# %%
linear_df1 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.515137354',
  '0.020107911',
  '0.517130224',
  '0.434502861',
  '0.515137354'],
 'mae score': ['147,706.506811',
  '226,976.760650',
  '147,606.503772',
  '157,037.560289',
  '147,706.506811'],
 'mse score': ['46,001,988,514.700203',
  '95,790,814,710.961456',
  '45,815,443,513.097862',
  '53,618,626,179.286659',
  '46,001,988,514.627281'],
 'r2 score': ['0.514766', '-0.010412', '0.516734', '0.434425', '0.514766'],
 'mean fit time': [0.001797962188720703,
  0.0018787860870361328,
  0.003125429153442383,
  0.0018703460693359375,
  0.0020323276519775392]})

# %%
linear_df2 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.288064360',
  '0.353216033',
  '0.288064360',
  '0.288064360',
  '0.288064360'],
 'mae score': ['145,476.615031',
  '146,964.883029',
  '145,476.615031',
  '145,476.615031',
  '145,476.615031'],
 'mse score': ['40,094,163,308.386154',
  '36,123,951,941.742821',
  '40,094,163,308.383446',
  '40,094,163,308.378860',
  '40,094,163,308.379684'],
 'r2 score': ['0.233826', '0.309694', '0.233826', '0.233826', '0.233826'],
 'mean fit time': [0.0, 0.0, 0.0, 0.000603342056274414, 0.0021683692932128905]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.288064360',
  '0.302486157',
  '0.302486157',
  '0.302486157'],
 'mae score': ['0.463259', '0.461195', '0.461195', '0.461195'],
 'mse score': ['0.406576', '0.398775', '0.398775', '0.398775'],
 'r2 score': ['0.233826', '0.248528', '0.248528', '0.248528'],
 'mean fit time': [0.0010613441467285157,
  0.001784515380859375,
  0.0022294998168945314,
  0.0]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost             -0.863496245  0.709294  1.160741
# 1       Gradient Boosting             -0.480421294  0.519072  0.804573
# 2  Hist Gradient Boosting              0.492989717  0.421461  0.280372
# 3           Random Forest             -0.513024336  0.559112  0.841728
#
#     r2 score  mean fit time
# 0  -1.187364       0.021404
# 1  -0.516181       0.025310
# 2   0.471652       0.093452
# 3  -0.586198       0.074117

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params             -0.013938664  0.572719  0.570457
# 1  Recursive Feature Elimination             -0.705674416  0.595010  0.905164
# 2    Sequential Feature Selector             -0.705182617  0.593837  0.904918
#
#     r2 score  mean fit time
# 0  -0.075000       0.002879
# 1  -0.705740       0.000788
# 2  -0.705276       0.000000

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.333670489  0.469973  0.364996
# 1  Sequential Feature Selector              0.021068089  0.527999  0.549147
#
#     r2 score  mean fit time
# 0   0.312182            0.0
# 1  -0.034843            0.0

# %%
lasso_df
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.288064360  145,476.615029
# 1              Select From Model              0.288066984  145,476.479733
# 2    Sequential Feature Selector              0.288066984  145,476.479733
# 3  Recursive Feature Elimination              0.288066984  145,476.479733
#
#                mse score  r2 score  mean fit time
# 0  40,094,163,307.607681  0.233826       0.000694
# 1  40,094,017,861.090286  0.233829       0.001691
# 2  40,094,017,861.090286  0.233829       0.000000
# 3  40,094,017,861.090286  0.233829       0.000000

# %%
linear_df1
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.515137354  147,706.506811
# 1              Select From Model              0.020107911  226,976.760650
# 2    Sequential Feature Selector              0.517130224  147,606.503772
# 3  Recursive Feature Elimination              0.434502861  157,037.560289
# 4             PolynomialFeatures              0.515137354  147,706.506811
#
#                mse score   r2 score  mean fit time
# 0  46,001,988,514.700203   0.514766       0.001798
# 1  95,790,814,710.961456  -0.010412       0.001879
# 2  45,815,443,513.097862   0.516734       0.003125
# 3  53,618,626,179.286659   0.434425       0.001870
# 4  46,001,988,514.627281   0.514766       0.002032

# %%
linear_df2
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.288064360  145,476.615031
# 1              Select From Model              0.353216033  146,964.883029
# 2    Sequential Feature Selector              0.288064360  145,476.615031
# 3  Recursive Feature Elimination              0.288064360  145,476.615031
# 4             PolynomialFeatures              0.288064360  145,476.615031
#
#                mse score  r2 score  mean fit time
# 0  40,094,163,308.386154  0.233826       0.000000
# 1  36,123,951,941.742821  0.309694       0.000000
# 2  40,094,163,308.383446  0.233826       0.000000
# 3  40,094,163,308.378860  0.233826       0.000603
# 4  40,094,163,308.379684  0.233826       0.002168

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.288064360  0.463259  0.406576
# 1              Select From Model              0.302486157  0.461195  0.398775
# 2    Sequential Feature Selector              0.302486157  0.461195  0.398775
# 3  Recursive Feature Elimination              0.302486157  0.461195  0.398775
#
#    r2 score  mean fit time
# 0  0.233826       0.001061
# 1  0.248528       0.001785
# 2  0.248528       0.002229
# 3  0.248528       0.000000
