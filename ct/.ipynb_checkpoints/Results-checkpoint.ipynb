# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.677293259',
  '0.795944074',
  '0.809934664',
  '0.772774429'],
 'mae score': ['0.586868', '0.257159', '0.254773', '0.260262'],
 'mse score': ['0.518730', '0.206186', '0.192069', '0.230179'],
 'r2 score': ['0.486347', '0.795833', '0.809811', '0.772074'],
 'mean fit time': [0.07409815788269043,
  0.19640874862670898,
  0.5079864978790283,
  1.1926444530487061]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.633172271', '0.589822843', '0.629311321'],
 'mae score': ['0.347391', '0.375426', '0.337795'],
 'mse score': ['0.371263', '0.415249', '0.375228'],
 'r2 score': ['0.632371', '0.588816', '0.628445'],
 'mean fit time': [0.0044743061065673825,
  0.008626079559326172,
  0.00397038459777832]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.641761289', '0.667222971'],
 'mae score': ['0.345852', '0.338976'],
 'mse score': ['0.362957', '0.339936'],
 'r2 score': ['0.640596', '0.663391'],
 'mean fit time': [0.0031785488128662108, 0.00042214393615722654]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.543668583',
  '0.000000000',
  '0.000000000',
  '0.000000000'],
 'mae score': ['0.426966', '0.631358', '0.631358', '0.631358'],
 'mse score': ['0.461484', '1.010076', '1.010076', '1.010076'],
 'r2 score': ['0.543033', '-0.000189', '-0.000189', '-0.000189'],
 'mean fit time': [0.003131723403930664,
  0.001806640625,
  0.0,
  0.0004275798797607422]})

# %%
linear_df_county = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.452133035',
  '0.082817228',
  '0.398619563',
  '0.544399401',
  '0.541774239'],
 'mae score': ['0.517894', '0.673448', '0.547379', '0.485035', '0.472677'],
 'mse score': ['0.470362', '0.759544', '0.519451', '0.393613', '0.388577'],
 'r2 score': ['0.430784', '0.080826', '0.371379', '0.523663', '0.529758'],
 'mean fit time': [0.0024937152862548827,
  0.0017273426055908203,
  0.0018399715423583984,
  0.002533149719238281,
  0.0031954765319824217]})

# %%
linear_df_major = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.543668583',
  '0.173897537',
  '0.481668992',
  '0.537550570',
  '0.730011202'],
 'mae score': ['0.426966', '0.569319', '0.440553', '0.429488', '0.321214'],
 'mse score': ['0.461484', '0.834368', '0.523535', '0.467730', '0.273449'],
 'r2 score': ['0.543033', '0.173800', '0.481590', '0.536848', '0.729228'],
 'mean fit time': [0.002002525329589844,
  0.0,
  0.0016293525695800781,
  0.002185344696044922,
  0.005221223831176758]}
)

# %%
linear_df_minor = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.690220941',
  '0.685384210',
  '0.685384244',
  '0.690220952',
  '0.690220951'],
 'mae score': ['0.627913', '0.617829', '0.617829', '0.627913', '0.627913'],
 'mse score': ['0.687797', '0.701177', '0.701177', '0.687796', '0.687796'],
 'r2 score': ['0.684929', '0.678800', '0.678800', '0.684929', '0.684929'],
 'mean fit time': [0.002525138854980469,
  0.0,
  0.0,
  0.001103353500366211,
  0.0033658027648925783]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.543668583',
  '0.173660776',
  '0.537439140',
  '0.537439140'],
 'mae score': ['0.426966', '0.568892', '0.428927', '0.428927'],
 'mse score': ['0.461484', '0.834602', '0.467832', '0.467832'],
 'r2 score': ['0.543033', '0.173567', '0.536747', '0.536747'],
 'mean fit time': [0.002858877182006836,
  0.00013957023620605468,
  0.0026226043701171875,
  0.0005514621734619141]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.677293259  0.586868  0.518730
# 1       Gradient Boosting              0.795944074  0.257159  0.206186
# 2  Hist Gradient Boosting              0.809934664  0.254773  0.192069
# 3           Random Forest              0.772774429  0.260262  0.230179
#
#    r2 score  mean fit time
# 0  0.486347       0.074098
# 1  0.795833       0.196409
# 2  0.809811       0.507986
# 3  0.772074       1.192644

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params              0.633172271  0.347391  0.371263
# 1  Recursive Feature Elimination              0.589822843  0.375426  0.415249
# 2    Sequential Feature Selector              0.629311321  0.337795  0.375228
#
#    r2 score  mean fit time
# 0  0.632371       0.004474
# 1  0.588816       0.008626
# 2  0.628445       0.003970

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.641761289  0.345852  0.362957
# 1  Sequential Feature Selector              0.667222971  0.338976  0.339936
#
#    r2 score  mean fit time
# 0  0.640596       0.003179
# 1  0.663391       0.000422

# %%
lasso_df
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.543668583  161,415.507137
# 1              Select From Model              0.543667469  161,414.537152
# 2    Sequential Feature Selector              0.481667819  166,551.563673
# 3  Recursive Feature Elimination              0.485148015  174,671.744413
#
#                mse score  r2 score  mean fit time
# 0  65,956,804,870.511917  0.543033       0.005729
# 1  65,956,962,680.225174  0.543032       0.000000
# 2  74,825,469,327.565704  0.481589       0.000000
# 3  74,359,301,827.326828  0.484819       0.000000

# %%
linear_df_county
# Out:
#                            model explained variance score      mae score  \
# 0                    Best Params              0.452133035  72,823.319033
# 1              Select From Model              0.082817228  94,696.451905
# 2    Sequential Feature Selector              0.398619563  76,969.424529
# 3  Recursive Feature Elimination              0.448799034  71,452.952334
# 4             PolynomialFeatures              0.541773228  66,465.137555
#
#                mse score  r2 score  mean fit time
# 0   9,300,191,238.785624  0.430784       0.000000
# 1  15,018,009,024.354263  0.080826       0.000810
# 2  10,270,788,087.659365  0.371379       0.000000
# 3   9,278,444,723.981607  0.432115       0.000643
# 4   7,683,112,979.457983  0.529757       0.003379

# %%
linear_df_major
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.543668583  0.426966  0.461484
# 1              Select From Model              0.173897537  0.569319  0.834368
# 2    Sequential Feature Selector              0.481668992  0.440553  0.523535
# 3  Recursive Feature Elimination              0.537550570  0.429488  0.467730
# 4             PolynomialFeatures              0.730011202  0.321214  0.273449
#
#    r2 score  mean fit time
# 0  0.543033       0.002003
# 1  0.173800       0.000000
# 2  0.481590       0.001629
# 3  0.536848       0.002185
# 4  0.729228       0.005221

# %%
linear_df_minor
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.690220952   70,443.592147
# 1              Select From Model              0.322419751  102,401.801154
# 2    Sequential Feature Selector              0.685384210   69,312.316022
# 3  Recursive Feature Elimination              0.690220952   70,443.592147
# 4             PolynomialFeatures              0.690220952   70,443.592147
#
#                mse score  r2 score  mean fit time
# 0   8,656,528,991.031015  0.684929       0.001804
# 1  18,636,218,379.184006  0.321700       0.003324
# 2   8,824,938,032.137716  0.678800       0.001651
# 3   8,656,528,991.035341  0.684929       0.002803
# 4   8,656,528,991.031836  0.684929       0.001410

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.543668583  0.426966  0.461484
# 1              Select From Model              0.173660776  0.568892  0.834602
# 2    Sequential Feature Selector              0.537439140  0.428927  0.467832
# 3  Recursive Feature Elimination              0.537439140  0.428927  0.467832
#
#    r2 score  mean fit time
# 0  0.543033       0.002859
# 1  0.173567       0.000140
# 2  0.536747       0.002623
# 3  0.536747       0.000551
