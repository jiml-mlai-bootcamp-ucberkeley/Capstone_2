# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.555359463',
  '0.632650045',
  '0.543123573',
  '0.660194370'],
 'mae score': ['0.497237', '0.441327', '0.480300', '0.416642'],
 'mse score': ['0.500958', '0.408047', '0.510044', '0.378796'],
 'r2 score': ['0.548978', '0.632628', '0.540798', '0.658963'],
 'mean fit time': [0.008153247833251952,
  0.02642989158630371,
  0.08887925148010253,
  0.08249411582946778]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.501674592', '0.633265979', '0.542394283'],
 'mae score': ['0.516455', '0.472611', '0.473491'],
 'mse score': ['0.556478', '0.407339', '0.508294'],
 'r2 score': ['0.498992', '0.633265', '0.542374'],
 'mean fit time': [0.001660919189453125,
  0.003329610824584961,
  0.00016808509826660156]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.609768181', '0.679135631'],
 'mae score': ['0.434423', '0.415878'],
 'mse score': ['0.434249', '0.360250'],
 'r2 score': ['0.609037', '0.675660'],
 'mean fit time': [0.0018507480621337891, 0.0016693115234375]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.645411530',
  '0.645410755',
  '0.643582607',
  '0.645410755'],
 'mae score': ['137,326.063760',
  '137,326.181853',
  '137,454.404213',
  '137,326.181853'],
 'mse score': ['40,949,254,598.853416',
  '40,949,345,970.590340',
  '41,166,448,556.896378',
  '40,949,345,970.590340'],
 'r2 score': ['0.645133', '0.645132', '0.643251', '0.645132'],
 'mean fit time': [0.000792694091796875,
  0.0017116069793701172,
  0.0031250476837158202,
  0.004064702987670898]})

# %%
linear_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.645411530',
  '0.605386169',
  '0.645411530',
  '0.645411530',
  '0.645411530'],
 'mae score': ['137,326.063760',
  '143,545.366674',
  '137,326.063760',
  '137,326.063760',
  '137,326.063760'],
 'mse score': ['40,949,254,598.846703',
  '45,536,162,342.388184',
  '40,949,254,598.846680',
  '40,949,254,598.846680',
  '40,949,254,598.846748'],
 'r2 score': ['0.645133', '0.605382', '0.645133', '0.645133', '0.645133'],
 'mean fit time': [0.002808237075805664,
  0.0017295360565185546,
  4.7588348388671874e-05,
  0.003127288818359375,
  0.0022246837615966797]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.645411530',
  '0.643000406',
  '0.643000406',
  '0.644285241'],
 'mae score': ['0.426054', '0.426649', '0.426649', '0.426398'],
 'mse score': ['0.394157', '0.396878', '0.396878', '0.395413'],
 'r2 score': ['0.645133', '0.642683', '0.642683', '0.644002'],
 'mean fit time': [0.0023032665252685548,
  0.0003398418426513672,
  0.0010141372680664063,
  0.001125478744506836]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.555359463  0.497237  0.500958
# 1       Gradient Boosting              0.632650045  0.441327  0.408047
# 2  Hist Gradient Boosting              0.543123573  0.480300  0.510044
# 3           Random Forest              0.660194370  0.416642  0.378796
#
#    r2 score  mean fit time
# 0  0.548978       0.008153
# 1  0.632628       0.026430
# 2  0.540798       0.088879
# 3  0.658963       0.082494

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params              0.501674592  0.516455  0.556478
# 1  Recursive Feature Elimination              0.633265979  0.472611  0.407339
# 2    Sequential Feature Selector              0.542394283  0.473491  0.508294
#
#    r2 score  mean fit time
# 0  0.498992       0.001661
# 1  0.633265       0.003330
# 2  0.542374       0.000168

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.609768181  0.434423  0.434249
# 1  Sequential Feature Selector              0.679135631  0.415878  0.360250
#
#    r2 score  mean fit time
# 0  0.609037       0.001851
# 1  0.675660       0.001669

# %%
lasso_df
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.645411530  137,326.063760
# 1              Select From Model              0.645410755  137,326.181853
# 2    Sequential Feature Selector              0.643582607  137,454.404213
# 3  Recursive Feature Elimination              0.645410755  137,326.181853
#
#                mse score  r2 score  mean fit time
# 0  40,949,254,598.853416  0.645133       0.000793
# 1  40,949,345,970.590340  0.645132       0.001712
# 2  41,166,448,556.896378  0.643251       0.003125
# 3  40,949,345,970.590340  0.645132       0.004065

# %%
linear_df
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.645411530  137,326.063760
# 1              Select From Model              0.605386169  143,545.366674
# 2    Sequential Feature Selector              0.645411530  137,326.063760
# 3  Recursive Feature Elimination              0.645411530  137,326.063760
# 4             PolynomialFeatures              0.645411530  137,326.063760
#
#                mse score  r2 score  mean fit time
# 0  40,949,254,598.846703  0.645133       0.002808
# 1  45,536,162,342.388184  0.605382       0.001730
# 2  40,949,254,598.846680  0.645133       0.000048
# 3  40,949,254,598.846680  0.645133       0.003127
# 4  40,949,254,598.846748  0.645133       0.002225

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.645411530  0.426054  0.394157
# 1              Select From Model              0.643000406  0.426649  0.396878
# 2    Sequential Feature Selector              0.643000406  0.426649  0.396878
# 3  Recursive Feature Elimination              0.644285241  0.426398  0.395413
#
#    r2 score  mean fit time
# 0  0.645133       0.002303
# 1  0.642683       0.000340
# 2  0.642683       0.001014
# 3  0.644002       0.001125
