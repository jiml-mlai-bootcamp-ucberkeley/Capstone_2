# %% [markdown]
# ## The goal of Decision Tree is to create a model that predicts the value of a target variable by learning simple decision rules inferred from the data features.

# %%
from warnings import filterwarnings
filterwarnings("ignore")

import sys
sys.path.append('../common')

from print_more_stuff import print_more_stuff
from regression_models import dosomething
from preprocessing import mean_and_std

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
outliers_df = pd.read_csv('outliers.csv')
outliers_df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
outliers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7617 entries, 0 to 7616
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             7617 non-null   float64
#  1   bath            7617 non-null   float64
#  2   acre_lot        7617 non-null   float64
#  3   zip_code        7617 non-null   float64
#  4   house_size      7617 non-null   float64
#  5   prev_sold_date  7617 non-null   object
#  6   price           7617 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 416.7+ KB

# %% [markdown]
# #### Create new feature prev_sold_year from prev_sold_date

# %%
outliers_df["prev_sold_year"] = pd.to_datetime(outliers_df["prev_sold_date"], format='%Y-%m-%d').dt.year
outliers_df.drop(columns=["prev_sold_date"],inplace=True)
outliers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7617 entries, 0 to 7616
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             7617 non-null   float64
#  1   bath            7617 non-null   float64
#  2   acre_lot        7617 non-null   float64
#  3   zip_code        7617 non-null   float64
#  4   house_size      7617 non-null   float64
#  5   price           7617 non-null   float64
#  6   prev_sold_year  7617 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 416.7 KB

# %%
params = {
    "data":outliers_df,
    "features_a":["prev_sold_year","zip_code"],
    "features_n":["bed","bath","acre_lot","house_size","price"]
}
normalize_df = mean_and_std(params)
normalize_df.tail()
# Out:
#            bed      bath  acre_lot  house_size     price  prev_sold_year  \
# 7612  1.488497 -0.428593 -0.066492    -0.28969  0.162589            2019
# 7613  0.594413  0.570365 -0.067547    -0.28969  1.723751            2016
# 7614  0.594413 -0.428593 -0.065437    -0.28969 -0.085459            2020
# 7615 -0.299671 -0.428593 -0.060161    -0.28969 -0.611793            2017
# 7616 -1.193755 -1.427551 -0.070713    -0.28969 -0.890571            2019
#
#       zip_code
# 7612    7304.0
# 7613    7307.0
# 7614    7734.0
# 7615    7403.0
# 7616    7462.0

# %%
correlation = normalize_df[["acre_lot","bed","bath","house_size","prev_sold_year","price"]].corr()
correlation["price"]
# Out:
# acre_lot          0.037786
# bed               0.413077
# bath              0.584972
# house_size        0.338367
# prev_sold_year    0.039965
# price             1.000000
# Name: price, dtype: float64

# %%
sns.heatmap(correlation, vmin=-1, vmax=1, cmap = 'coolwarm', annot=True, fmt='.2f', linewidths=0.1)
plt.title("Correlation Between Variables", pad=20)
# Out:
# Text(0.5, 1.0, 'Correlation Between Variables')

# %%
'''
'''
savefeatures = ["latitude","longitude"]
for feature, value in correlation["price"].items():
    if abs(value) < 0.81 and abs(value) >= 0.20:
        savefeatures.append(feature)

print(savefeatures)
# Out:
# ['latitude', 'longitude', 'bed', 'bath', 'house_size']

# %%
pariplot_features = []
for feature, value in correlation["price"].items():
        pariplot_features.append(feature)

# %%
sns.pairplot(normalize_df[pariplot_features])

# %% [markdown]
# #### Create a new feature in the housing data for Zip Code with a leading zero

# %%
outliers_df["zip_code_str"] = np.where(outliers_df.zip_code.apply(int) < 10000,'0'+ outliers_df.zip_code.apply(int).apply(str),normalize_df.zip_code.apply(int).apply(str))
outliers_df.head()
# Out:
#    bed  bath  acre_lot  zip_code  house_size     price  prev_sold_year  \
# 0  3.0   2.0      0.14    7001.0      1542.0  305100.0            2022
# 1  3.0   2.0      0.11    7001.0      1500.0  479000.0            2016
# 2  3.0   2.0      0.17    7001.0      7501.0  340000.0            2021
# 3  5.0   2.0      0.18    7001.0      1387.0  484000.0            2020
# 4  3.0   2.0      0.17    7001.0      1500.0  425000.0            2019
#
#   zip_code_str
# 0        07001
# 1        07001
# 2        07001
# 3        07001
# 4        07001

# %% [markdown]
# #### Create a new feature in the Lat/Long data for Zip Code with a leading zero

# %%
zip_lon_lat = pd.read_csv('nj_zip-lon-lat.csv')
zip_lon_lat["zip_code_str"] = np.where(zip_lon_lat.zip_code.apply(int) < 10000,'0'+ zip_lon_lat.zip_code.apply(int).apply(str),zip_lon_lat.zip_code.apply(int).apply(str))
zip_lon_lat.head()
# Out:
#    zip_code   latitude  longitude zip_code_str
# 0      7001  40.582316 -74.271506        07001
# 1      7002  40.662338 -74.110275        07002
# 2      7003  40.809128 -74.187155        07003
# 3      7004  40.882508 -74.304593        07004
# 4      7005  40.932771 -74.417304        07005

# %% [markdown]
# #### Merge the Lat/Long data with the housing data using Zip Code with a leading zero

# %%
merged_df = pd.merge(outliers_df, zip_lon_lat, how='inner', on="zip_code_str")
merged_df.tail()
# Out:
#       bed  bath  acre_lot  zip_code_x  house_size     price  prev_sold_year  \
# 7609  5.0   4.0      0.91      8848.0      1500.0  485000.0            2017
# 7610  4.0   3.0      2.17      8825.0      1500.0  510000.0            2016
# 7611  3.0   2.0      0.12      7012.0      1500.0  499000.0            2021
# 7612  3.0   3.0      0.13      7012.0      1500.0  530000.0            2022
# 7613  4.0   3.0      0.11      7640.0      1500.0  720000.0            2016
#
#      zip_code_str  zip_code_y   latitude  longitude
# 7609        08848        8848  40.594266 -75.096659
# 7610        08825        8825  40.514169 -75.027112
# 7611        07012        7012  40.848398 -74.160266
# 7612        07012        7012  40.848398 -74.160266
# 7613        07640        7640  40.991681 -73.980202

# %% [markdown]
# #### Create common variables to store frequently used values.

# %%
#features = ["latitude","longitude","bed","bath","house_size"]
features = savefeatures
num_features_to_select = len(features)-1
random_state_value = 42

# %% [markdown]
# #### Datasets for modeling, testing the models, and making predictions.

# %%
X = merged_df[features]
y = merged_df["price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state_value)

# %% [markdown]
# #### Variable to store the results generated by the models.

# %%
results_dict = {"model":[], "explained variance score":[],"mae score":[],"mse score":[],"r2 score":[], "mean fit time":[]}

# %% [markdown]
# #### Function to format the results generated by the models.

# %%
def results_dict_append(rtnval):
    results_dict["model"].append(rtnval["model"])
    results_dict["explained variance score"].append(rtnval["explained variance score"])
    results_dict["mae score"].append(rtnval["mae score"])
    results_dict["mse score"].append(rtnval["mse score"])
    results_dict["r2 score"].append(rtnval["r2 score"])
    results_dict["mean fit time"].append(rtnval["mean fit time"])

# %% [markdown]
# ### GridSearchCV exhaustively generates candidates from a grid of parameter values specified.

# %%
params = {'max_depth': range(5,15,1),
         'random_state':[42]}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid=params).fit(X_train, y_train)
grid_train_acc = grid.score(X_train, y_train)
grid_test_acc = grid.score(X_test, y_test)
best_params = grid.best_params_
best_params
# Out:
# {'max_depth': 10, 'random_state': 42}

# %% [markdown]
# #### The best params attribute will be used to fit  model with the training data and make a prediction with the test data.

# %%
dtree = dosomething("Decision Tree","Decision Tree Best Params", merged_df, features, "price", best_params)
results_dict_append(dtree["results"])
dtree_bp_predict = dtree["predictions"]
# Out:
# The selected features are: ['latitude', 'longitude', 'bed', 'bath', 'house_size']
# Decision Tree Best Params EVS = 0.506696541
# Decision Tree Best Params MSE = 79,542,892,706.848709
# Decision Tree Best Params MAE = 161,211.678091
# Decision Tree Best Params R2 = 0.505739
# Decision Tree Best Params Fit Time = 0.01336665153503418

# %% [markdown]
# #### cost_complexity_pruning_path

# %%
path = DecisionTreeRegressor().cost_complexity_pruning_path(X_train, y_train)

ccp_alphas = path.ccp_alphas
impurities = path.impurities

plt.step(ccp_alphas[:-1], impurities[:-1], '--o')
plt.title('Impurity vs. Effective Alpha')
plt.xlabel('Effective Alphas')
plt.ylabel('Total Impurity of Leaves');

# %% [markdown]
# ### Recursive feature elimination uses an external estimator that assigns weights to features with the goal of selecting features by recursively considering smaller and smaller sets of features.

# %%
dtree_rfe = dosomething("Decision Tree","Recursive Feature Elimination", merged_df, features, "price")
results_dict_append(dtree_rfe["results"])
dtree_rfe_predict = dtree_rfe["predictions"]
# Out:
# The selected features are: ['latitude', 'longitude', 'bath', 'house_size']
# Recursive Feature Elimination EVS = 0.530367988
# Recursive Feature Elimination MSE = 75,913,927,824.741852
# Recursive Feature Elimination MAE = 161,691.489163
# Recursive Feature Elimination R2 = 0.528288
# Recursive Feature Elimination Fit Time = 0.02187509536743164

# %% [markdown]
# ###  Sequential Feature Selector (forward selection) adds features to form a feature subset in a greedy fashion. At each stage, this estimator chooses the best feature to add or remove based on the cross-validation score of an estimator.

# %%
dtree_sfs = dosomething("Decision Tree","Sequential Feature Selector", merged_df, features, "price")
results_dict_append(dtree_sfs["results"])
dtree_sfs_predict = dtree_sfs["predictions"]
# Out:
# The selected features are: ['longitude', 'bed', 'bath', 'house_size']
# Sequential Feature Selector EVS = 0.392758386
# Sequential Feature Selector MSE = 97,754,618,200.889572
# Sequential Feature Selector MAE = 181,112.257321
# Sequential Feature Selector R2 = 0.392575
# Sequential Feature Selector Fit Time = 0.018908929824829102

# %% [markdown]
# #### Graphing the results works best when the data is provided in a DataFrame.

# %%
dtree_bp_predict_df = pd.DataFrame(dtree_bp_predict).reset_index()
dtree_bp_predict_df.rename(columns={0: "prediction"},inplace=True)

dtree_sfs_predict_df = pd.DataFrame(dtree_sfs_predict).reset_index()
dtree_sfs_predict_df.rename(columns={0: "prediction"},inplace=True)

dtree_rfe_predict_df = pd.DataFrame(dtree_rfe_predict).reset_index()
dtree_rfe_predict_df.rename(columns={0: "prediction"},inplace=True)

y_test_df = pd.DataFrame(y_test).reset_index()

# %% [markdown]
# #### The predictions provided by the best parameters have the appearance of banding.  I will conduct more testing to determine if this is acceptable or if this is a case of underfitting or overfitting.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.ticklabel_format(style='plain')
ax.yaxis.set_major_formatter('${x:1,.0f}')
ax.xaxis.set_major_formatter(' ')

plt.scatter(y_test_df.index,y_test_df["price"], color="red")
plt.scatter(dtree_bp_predict_df.index,dtree_bp_predict_df["prediction"], color="black")
plt.show()

# %% [markdown]
# #### Scatter Plot graph of the results of Recursive Feature Elimination, Sequential Feature Selection, and Test Data.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.ticklabel_format(style='plain')
ax.yaxis.set_major_formatter('${x:1,.0f}')
ax.xaxis.set_major_formatter(' ')

plt.scatter(y_test_df.index,y_test_df["price"], color="red")
plt.scatter(dtree_rfe_predict_df.index,dtree_rfe_predict_df["prediction"], color="blue")
plt.scatter(dtree_sfs_predict_df.index,dtree_sfs_predict_df["prediction"], color="green")
plt.show()

# %% [markdown]
# #### Output the results so they can be copied into another Notebook comparing the results of all the models.

# %%
results_dict
# Out:
# {'model': ['Decision Tree Best Params',
#   'Recursive Feature Elimination',
#   'Sequential Feature Selector'],
#  'explained variance score': ['0.506696541', '0.530367988', '0.392758386'],
#  'mae score': ['161,211.678091', '161,691.489163', '181,112.257321'],
#  'mse score': ['79,542,892,706.848709',
#   '75,913,927,824.741852',
#   '97,754,618,200.889572'],
#  'r2 score': ['0.505739', '0.528288', '0.392575'],
#  'mean fit time': [0.01336665153503418,
#   0.02187509536743164,
#   0.018908929824829102]}

# %%
model_comparisons = pd.DataFrame(results_dict).set_index('model')
model_comparisons
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                  0.506696541  161,211.678091
# Recursive Feature Elimination              0.530367988  161,691.489163
# Sequential Feature Selector                0.392758386  181,112.257321
#
#                                            mse score  r2 score  mean fit time
# model
# Decision Tree Best Params      79,542,892,706.848709  0.505739       0.013367
# Recursive Feature Elimination  75,913,927,824.741852  0.528288       0.021875
# Sequential Feature Selector    97,754,618,200.889572  0.392575       0.018909

# %%
scaler = StandardScaler()
prices = outliers_df[["price"]]
stdscaler_fit = scaler.fit(prices)
stdscaler_transform = scaler.transform(prices)
stdscaler_transform
# Out:
# array([[-0.56821666],
#        [-0.13725882],
#        [-0.48172771],
#        ...,
#        [-0.08546458],
#        [-0.61183286],
#        [-0.89062962]])

# %%
plt.hist(stdscaler_transform, bins=100)
# Out:
# (array([ 12.,  38.,  67., 100., 120., 188., 268., 272., 401., 332., 379.,
#         420., 539., 535., 339., 357., 298., 253., 320., 137., 221., 116.,
#         159., 132., 153., 138.,  77., 126.,  67.,  90.,  56., 100.,  68.,
#          38.,  70.,   2.,   9.,  45.,   4.,  21.,  15.,  49.,   5.,  31.,
#          48.,   3.,  25.,   8.,  27.,   8.,  13.,  46.,   4.,  10.,   7.,
#          23.,   6.,   4.,  19.,   3.,  13.,   7.,  15.,   9.,   2.,   9.,
#           0.,   2.,  26.,   0.,   2.,   1.,   8.,   0.,  10.,  11.,   0.,
#           4.,   2.,   7.,   0.,   3.,   8.,   1.,   3.,   1.,  16.,   0.,
#           0.,   8.,   0.,   1.,   1.,   4.,   3.,   0.,  11.,   0.,   2.,
#           6.]),
#  array([-1.32431347, -1.25244586, -1.18057825, -1.10871064, -1.03684303,
#         -0.96497542, -0.89310781, -0.8212402 , -0.74937259, -0.67750499,
#         -0.60563738, -0.53376977, -0.46190216, -0.39003455, -0.31816694,
#         -0.24629933, -0.17443172, -0.10256412, -0.03069651,  0.0411711 ,
#          0.11303871,  0.18490632,  0.25677393,  0.32864154,  0.40050915,
#          0.47237675,  0.54424436,  0.61611197,  0.68797958,  0.75984719,
#          0.8317148 ,  0.90358241,  0.97545002,  1.04731763,  1.11918523,
#          1.19105284,  1.26292045,  1.33478806,  1.40665567,  1.47852328,
#          1.55039089,  1.6222585 ,  1.6941261 ,  1.76599371,  1.83786132,
#          1.90972893,  1.98159654,  2.05346415,  2.12533176,  2.19719937,
#          2.26906697,  2.34093458,  2.41280219,  2.4846698 ,  2.55653741,
#          2.62840502,  2.70027263,  2.77214024,  2.84400784,  2.91587545,
#          2.98774306,  3.05961067,  3.13147828,  3.20334589,  3.2752135 ,
#          3.34708111,  3.41894872,  3.49081632,  3.56268393,  3.63455154,
#          3.70641915,  3.77828676,  3.85015437,  3.92202198,  3.99388959,
#          4.06575719,  4.1376248 ,  4.20949241,  4.28136002,  4.35322763,
#          4.42509524,  4.49696285,  4.56883046,  4.64069806,  4.71256567,
#          4.78443328,  4.85630089,  4.9281685 ,  5.00003611,  5.07190372,
#          5.14377133,  5.21563893,  5.28750654,  5.35937415,  5.43124176,
#          5.50310937,  5.57497698,  5.64684459,  5.7187122 ,  5.79057981,
#          5.86244741]),
#  <BarContainer object of 100 artists>)
