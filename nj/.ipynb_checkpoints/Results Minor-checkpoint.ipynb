# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.555359463',
  '0.632650045',
  '0.543123573',
  '0.660194370'],
 'mae score': ['0.497237', '0.441327', '0.480300', '0.416642'],
 'mse score': ['0.500958', '0.408047', '0.510044', '0.378796'],
 'r2 score': ['0.548978', '0.632628', '0.540798', '0.658963'],
 'mean fit time': [0.008153247833251952,
  0.02642989158630371,
  0.08887925148010253,
  0.08249411582946778]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.501674592', '0.633265979', '0.542394283'],
 'mae score': ['0.516455', '0.472611', '0.473491'],
 'mse score': ['0.556478', '0.407339', '0.508294'],
 'r2 score': ['0.498992', '0.633265', '0.542374'],
 'mean fit time': [0.001660919189453125,
  0.003329610824584961,
  0.00016808509826660156]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.609768181', '0.679135631'],
 'mae score': ['0.434423', '0.415878'],
 'mse score': ['0.434249', '0.360250'],
 'r2 score': ['0.609037', '0.675660'],
 'mean fit time': [0.0018507480621337891, 0.0016693115234375]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.645411525',
  '0.000000000',
  '0.000000000',
  '0.000000000'],
 'mae score': ['0.426054', '0.760896', '0.760896', '0.760896'],
 'mse score': ['0.394157', '1.120905', '1.120905', '1.120905'],
 'r2 score': ['0.645133', '-0.009171', '-0.009171', '-0.009171'],
 'mean fit time': [0.0023000240325927734, 0.0, 0.0, 0.0013176441192626954]})

# %%
linear_df1 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.386026340',
  '0.116952080',
  '0.370146032',
  '0.384446103',
  '0.630673063'],
 'mae score': ['0.594675', '0.745060', '0.604218', '0.592967', '0.474733'],
 'mse score': ['0.918056', '1.329475', '0.944532', '0.921182', '0.560007'],
 'r2 score': ['0.380395', '0.102724', '0.362526', '0.378285', '0.622046'],
 'mean fit time': [0.002628660202026367,
  0.003465080261230469,
  0.003130054473876953,
  0.0017464160919189453,
  0.002924537658691406]})

# %%
linear_df2 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.645420057',
  '0.000000000',
  '0.643587474',
  '0.643587474',
  '0.645411530'],
 'mae score': ['0.426002', '0.760896', '0.426440', '0.426440', '0.426054'],
 'mse score': ['0.394139', '1.120905', '0.396241', '0.396241', '0.394157'],
 'r2 score': ['0.645149', '-0.009171', '0.643257', '0.643257', '0.645133'],
 'mean fit time': [0.0031262874603271485,
  0.0009585380554199219,
  0.0,
  0.003482627868652344,
  0.0015013694763183593]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.645411530',
  '0.643000406',
  '0.643000406',
  '0.644285241'],
 'mae score': ['0.426054', '0.426649', '0.426649', '0.426398'],
 'mse score': ['0.394157', '0.396878', '0.396878', '0.395413'],
 'r2 score': ['0.645133', '0.642683', '0.642683', '0.644002'],
 'mean fit time': [0.0023032665252685548,
  0.0003398418426513672,
  0.0010141372680664063,
  0.001125478744506836]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.555359463  0.497237  0.500958
# 1       Gradient Boosting              0.632650045  0.441327  0.408047
# 2  Hist Gradient Boosting              0.543123573  0.480300  0.510044
# 3           Random Forest              0.660194370  0.416642  0.378796
#
#    r2 score  mean fit time
# 0  0.548978       0.008153
# 1  0.632628       0.026430
# 2  0.540798       0.088879
# 3  0.658963       0.082494

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params              0.501674592  0.516455  0.556478
# 1  Recursive Feature Elimination              0.633265979  0.472611  0.407339
# 2    Sequential Feature Selector              0.542394283  0.473491  0.508294
#
#    r2 score  mean fit time
# 0  0.498992       0.001661
# 1  0.633265       0.003330
# 2  0.542374       0.000168

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.609768181  0.434423  0.434249
# 1  Sequential Feature Selector              0.679135631  0.415878  0.360250
#
#    r2 score  mean fit time
# 0  0.609037       0.001851
# 1  0.675660       0.001669

# %%
lasso_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.645411525  0.426054  0.394157
# 1              Select From Model              0.000000000  0.760896  1.120905
# 2    Sequential Feature Selector              0.000000000  0.760896  1.120905
# 3  Recursive Feature Elimination              0.000000000  0.760896  1.120905
#
#     r2 score  mean fit time
# 0   0.645133       0.002300
# 1  -0.009171       0.000000
# 2  -0.009171       0.000000
# 3  -0.009171       0.001318

# %%
linear_df1
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.386026340  0.594675  0.918056
# 1              Select From Model              0.116952080  0.745060  1.329475
# 2    Sequential Feature Selector              0.370146032  0.604218  0.944532
# 3  Recursive Feature Elimination              0.384446103  0.592967  0.921182
# 4             PolynomialFeatures              0.630673063  0.474733  0.560007
#
#    r2 score  mean fit time
# 0  0.380395       0.002629
# 1  0.102724       0.003465
# 2  0.362526       0.003130
# 3  0.378285       0.001746
# 4  0.622046       0.002925

# %%
linear_df2
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.645420057  0.426002  0.394139
# 1              Select From Model              0.000000000  0.760896  1.120905
# 2    Sequential Feature Selector              0.643587474  0.426440  0.396241
# 3  Recursive Feature Elimination              0.643587474  0.426440  0.396241
# 4             PolynomialFeatures              0.645411530  0.426054  0.394157
#
#     r2 score  mean fit time
# 0   0.645149       0.003126
# 1  -0.009171       0.000959
# 2   0.643257       0.000000
# 3   0.643257       0.003483
# 4   0.645133       0.001501

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.645411530  0.426054  0.394157
# 1              Select From Model              0.643000406  0.426649  0.396878
# 2    Sequential Feature Selector              0.643000406  0.426649  0.396878
# 3  Recursive Feature Elimination              0.644285241  0.426398  0.395413
#
#    r2 score  mean fit time
# 0  0.645133       0.002303
# 1  0.642683       0.000340
# 2  0.642683       0.001014
# 3  0.644002       0.001125
