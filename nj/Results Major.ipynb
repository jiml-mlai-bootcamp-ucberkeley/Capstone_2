# %%
import pandas as pd

# %%
boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.445671486',
  '0.610065213',
  '0.696329826',
  '0.644893924'],
 'mae score': ['0.689026', '0.374977', '0.322916', '0.341834'],
 'mse score': ['0.759528', '0.386733', '0.301281', '0.352455'],
 'r2 score': ['0.233130', '0.609528', '0.695806', '0.644138'],
 'mean fit time': [0.065769624710083,
  0.34974365234375,
  0.6046155452728271,
  3.1202785968780518]})

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.510980541', '0.516804918', '0.346617673'],
 'mae score': ['0.399318', '0.406072', '0.458246'],
 'mse score': ['0.485324', '0.480182', '0.650072'],
 'r2 score': ['0.509984', '0.515176', '0.343644'],
 'mean fit time': [0.012074565887451172,
  0.01891798973083496,
  0.019588136672973634]})

# %%
knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.505118797', '0.547632250'],
 'mae score': ['0.409941', '0.394364'],
 'mse score': ['0.490371', '0.448370'],
 'r2 score': ['0.504889', '0.547296'],
 'mean fit time': [0.0006242752075195313, 0.0048237800598144535]})

# %%
lasso_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.389265833',
  '0.389266234',
  '0.378652712',
  '0.385856612'],
 'mae score': ['202,648.955983',
  '202,648.235990',
  '204,878.518872',
  '203,907.959239'],
 'mse score': ['98,292,111,348.887619',
  '98,292,046,996.143082',
  '100,001,498,876.605911',
  '98,836,621,981.127274'],
 'r2 score': ['0.389235', '0.389236', '0.378614', '0.385852'],
 'mean fit time': [0.4885528087615967,
  0.011399936676025391,
  0.008382511138916016,
  0.007321929931640625]})

# %%
linear_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.389265833',
  '0.363106878',
  '0.378652172',
  '0.385856158',
  '0.485385078'],
 'mae score': ['0.502728', '0.507059', '0.508261', '0.505853', '0.435518'],
 'mse score': ['0.604917', '0.630796', '0.615438', '0.608269', '0.509937'],
 'r2 score': ['0.389235', '0.363107', '0.378613', '0.385852', '0.485134'],
 'mean fit time': [0.0035414695739746094,
  0.0,
  0.0031839847564697266,
  0.005499029159545898,
  0.008457422256469727]})

# %%
ridge_df = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.389265833',
  '0.363102382',
  '0.378668415',
  '0.385872062'],
 'mae score': ['0.502728', '0.507040', '0.508182', '0.505782'],
 'mse score': ['0.604917', '0.630800', '0.615422', '0.608253'],
 'r2 score': ['0.389235', '0.363102', '0.378629', '0.385867'],
 'mean fit time': [0.0025375843048095702,
  0.0015167713165283204,
  0.0018994331359863282,
  0.0018442630767822265]})

# %%
boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.445671486  0.689026  0.759528
# 1       Gradient Boosting              0.610065213  0.374977  0.386733
# 2  Hist Gradient Boosting              0.696329826  0.322916  0.301281
# 3           Random Forest              0.644893924  0.341834  0.352455
#
#    r2 score  mean fit time
# 0  0.233130       0.065770
# 1  0.609528       0.349744
# 2  0.695806       0.604616
# 3  0.644138       3.120279

# %%
decision_tree_df
# Out:
#                            model explained variance score mae score mse score  \
# 0      Decision Tree Best Params              0.510980541  0.399318  0.485324
# 1  Recursive Feature Elimination              0.516804918  0.406072  0.480182
# 2    Sequential Feature Selector              0.346617673  0.458246  0.650072
#
#    r2 score  mean fit time
# 0  0.509984       0.012075
# 1  0.515176       0.018918
# 2  0.343644       0.019588

# %%
knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.505118797  0.409941  0.490371
# 1  Sequential Feature Selector              0.547632250  0.394364  0.448370
#
#    r2 score  mean fit time
# 0  0.504889       0.000624
# 1  0.547296       0.004824

# %%
lasso_df
# Out:
#                            model explained variance score       mae score  \
# 0                    Best Params              0.389265833  202,648.955983
# 1              Select From Model              0.389266234  202,648.235990
# 2    Sequential Feature Selector              0.378652712  204,878.518872
# 3  Recursive Feature Elimination              0.385856612  203,907.959239
#
#                 mse score  r2 score  mean fit time
# 0   98,292,111,348.887619  0.389235       0.488553
# 1   98,292,046,996.143082  0.389236       0.011400
# 2  100,001,498,876.605911  0.378614       0.008383
# 3   98,836,621,981.127274  0.385852       0.007322

# %%
linear_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.389265833  0.502728  0.604917
# 1              Select From Model              0.363106878  0.507059  0.630796
# 2    Sequential Feature Selector              0.378652172  0.508261  0.615438
# 3  Recursive Feature Elimination              0.385856158  0.505853  0.608269
# 4             PolynomialFeatures              0.485385078  0.435518  0.509937
#
#    r2 score  mean fit time
# 0  0.389235       0.003541
# 1  0.363107       0.000000
# 2  0.378613       0.003184
# 3  0.385852       0.005499
# 4  0.485134       0.008457

# %%
ridge_df
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.389265833  0.502728  0.604917
# 1              Select From Model              0.363102382  0.507040  0.630800
# 2    Sequential Feature Selector              0.378668415  0.508182  0.615422
# 3  Recursive Feature Elimination              0.385872062  0.505782  0.608253
#
#    r2 score  mean fit time
# 0  0.389235       0.002538
# 1  0.363102       0.001517
# 2  0.378629       0.001899
# 3  0.385867       0.001844
