# %%
import pandas as pd

# %% [markdown]
# ## The R2 score will be used for determining the Best Results.

# %% [markdown]
# ### For many of them, there were similar values that were in very close proximity.
# ### The values presented here are the ones that I found to be "best".

# %% [markdown]
# #### One strange result that I found was that Lasso didn't perform well with Normalized data.
# #### I completed the analysis with Normalized data to make it the same as the others.

# %% [markdown]
# ### The first state I worked on in this project was NJ.
# ### Boosting, Decision Tree, and KNN performed best with State level data.
# ### Except for Lasso, the other models improved with Local level data.

# %%
nj_major_boost_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.445671486',
  '0.610065213',
  '0.696329826',
  '0.644893924'],
 'mae score': ['0.689026', '0.374977', '0.322916', '0.341834'],
 'mse score': ['0.759528', '0.386733', '0.301281', '0.352455'],
 'r2 score': ['0.233130', '0.609528', '0.695806', '0.644138'],
 'mean fit time': [0.065769624710083,
  0.34974365234375,
  0.6046155452728271,
  3.1202785968780518]})

# %%
nj_minor_knn_df = pd.DataFrame({'model': ['Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.609768181', '0.679135631'],
 'mae score': ['0.434423', '0.415878'],
 'mse score': ['0.434249', '0.360250'],
 'r2 score': ['0.609037', '0.675660'],
 'mean fit time': [0.0018507480621337891, 0.0016693115234375]})

# %%
nj_major_boost_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.445671486  0.689026  0.759528
# 1       Gradient Boosting              0.610065213  0.374977  0.386733
# 2  Hist Gradient Boosting              0.696329826  0.322916  0.301281
# 3           Random Forest              0.644893924  0.341834  0.352455
#
#    r2 score  mean fit time
# 0  0.233130       0.065770
# 1  0.609528       0.349744
# 2  0.695806       0.604616
# 3  0.644138       3.120279

# %%
nj_minor_knn_df
# Out:
#                          model explained variance score mae score mse score  \
# 0                  Best Params              0.609768181  0.434423  0.434249
# 1  Sequential Feature Selector              0.679135631  0.415878  0.360250
#
#    r2 score  mean fit time
# 0  0.609037       0.001851
# 1  0.675660       0.001669

# %% [markdown]
# ####  Nitpicking on the values for NJ, Hist Gradient Boosting provided a slightly better R2 score at the State level.
# ####  However KNN with Sequential Feature Selector ran faster with less data but a slightly lower R2 score for Local data.

# %%
ny_major_boost_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.561798842',
  '0.697087706',
  '0.765378203',
  '0.740545286'],
 'mae score': ['0.548722', '0.277870', '0.228738', '0.231710'],
 'mse score': ['0.569753', '0.287812', '0.222997', '0.246532'],
 'r2 score': ['0.400355', '0.697087', '0.765304', '0.740533'],
 'mean fit time': [0.0986668586730957,
  0.5893467426300049,
  0.5267816543579101,
  4.1320109367370605]})

# %%
ny_minor_boost_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.726025110',
  '0.794287996',
  '0.721259049',
  '0.791359329'],
 'mae score': ['0.354560', '0.316121', '0.344220', '0.320648'],
 'mse score': ['0.244248', '0.175517', '0.237900', '0.178123'],
 'r2 score': ['0.713730', '0.794285', '0.721169', '0.791231'],
 'mean fit time': [0.006557559967041016,
  0.023104381561279298,
  0.08960494995117188,
  0.07371926307678223]})

# %%
ny_major_boost_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.561798842  0.548722  0.569753
# 1       Gradient Boosting              0.697087706  0.277870  0.287812
# 2  Hist Gradient Boosting              0.765378203  0.228738  0.222997
# 3           Random Forest              0.740545286  0.231710  0.246532
#
#    r2 score  mean fit time
# 0  0.400355       0.098667
# 1  0.697087       0.589347
# 2  0.765304       0.526782
# 3  0.740533       4.132011

# %%
ny_minor_boost_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.726025110  0.354560  0.244248
# 1       Gradient Boosting              0.794287996  0.316121  0.175517
# 2  Hist Gradient Boosting              0.721259049  0.344220  0.237900
# 3           Random Forest              0.791359329  0.320648  0.178123
#
#    r2 score  mean fit time
# 0  0.713730       0.006558
# 1  0.794285       0.023104
# 2  0.721169       0.089605
# 3  0.791231       0.073719

# %% [markdown]
# ####  Just like the values for NJ, for NY the State level Hist Gradient Boosting provided a slightly better R2 score.
# ####  However Gradient Boosting provided the best results at the local level.

# %% [markdown]
# ### For Pennsylvania, analysis for both State and Local level data was performed.
# #### Most of the Local results were not useful but the "best" results are presented here.

# %%
pa_major_boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.309311667',
  '0.699047770',
  '0.637113535',
  '0.631574270'],
 'mae score': ['0.647211', '0.354180', '0.377455', '0.376502'],
 'mse score': ['0.851915', '0.320033', '0.385532', '0.391075'],
 'r2 score': ['0.197421', '0.698500', '0.636794', '0.631573'],
 'mean fit time': [0.06627044677734376,
  0.1663498878479004,
  0.5150489330291748,
  1.018368673324585]})

# %%
pa_minor_linear_df1 = pd.DataFrame({'model': ['Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination',
  'PolynomialFeatures'],
 'explained variance score': ['0.515137354',
  '0.020107911',
  '0.517130224',
  '0.517130224',
  '0.515137354'],
 'mae score': ['0.456133', '0.700928', '0.455824', '0.455824', '0.456133'],
 'mse score': ['0.438693', '0.913498', '0.436914', '0.436914', '0.438693'],
 'r2 score': ['0.514766', '-0.010412', '0.516734', '0.516734', '0.514766'],
 'mean fit time': [0.0024634361267089843,
  0.0,
  0.0016897201538085937,
  0.0,
  0.004961442947387695]})

# %%
pa_major_boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.309311667  0.647211  0.851915
# 1       Gradient Boosting              0.699047770  0.354180  0.320033
# 2  Hist Gradient Boosting              0.637113535  0.377455  0.385532
# 3           Random Forest              0.631574270  0.376502  0.391075
#
#    r2 score  mean fit time
# 0  0.197421       0.066270
# 1  0.698500       0.166350
# 2  0.636794       0.515049
# 3  0.631573       1.018369

# %%
pa_minor_linear_df1
# Out:
#                            model explained variance score mae score mse score  \
# 0                    Best Params              0.515137354  0.456133  0.438693
# 1              Select From Model              0.020107911  0.700928  0.913498
# 2    Sequential Feature Selector              0.517130224  0.455824  0.436914
# 3  Recursive Feature Elimination              0.517130224  0.455824  0.436914
# 4             PolynomialFeatures              0.515137354  0.456133  0.438693
#
#     r2 score  mean fit time
# 0   0.514766       0.002463
# 1  -0.010412       0.000000
# 2   0.516734       0.001690
# 3   0.516734       0.000000
# 4   0.514766       0.004961

# %% [markdown]
# ####  Just like the values for NJ & NY, for Pennsylvania the State level Hist Gradient Boosting provided a slightly better R2 score.
# ####  For the Local level data, only Select From Model peformed poorly.  The other four models were very close.

# %% [markdown]
# ### For Connecticut, only the State level data is presented.
# #### Local level data was processed with the Linear model, but the results were not compelling enough to be presented.

# %%
ct_boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.677293259',
  '0.795944074',
  '0.809934664',
  '0.772774429'],
 'mae score': ['0.586868', '0.257159', '0.254773', '0.260262'],
 'mse score': ['0.518730', '0.206186', '0.192069', '0.230179'],
 'r2 score': ['0.486347', '0.795833', '0.809811', '0.772074'],
 'mean fit time': [0.07409815788269043,
  0.19640874862670898,
  0.5079864978790283,
  1.1926444530487061]})

# %%
ct_boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.677293259  0.586868  0.518730
# 1       Gradient Boosting              0.795944074  0.257159  0.206186
# 2  Hist Gradient Boosting              0.809934664  0.254773  0.192069
# 3           Random Forest              0.772774429  0.260262  0.230179
#
#    r2 score  mean fit time
# 0  0.486347       0.074098
# 1  0.795833       0.196409
# 2  0.809811       0.507986
# 3  0.772074       1.192644

# %% [markdown]
# ####  Just like the values for other states, for Connecticut the State level Hist Gradient Boosting provided a slightly better R2 score.

# %% [markdown]
# ### For Massachusettes, only the State level data is presented.
# #### Local level data was processed with the Linear model, but the results were not compelling enough to be presented.

# %%
ma_boosting_df = pd.DataFrame({'model': ['Ada Boost',
  'Gradient Boosting',
  'Hist Gradient Boosting',
  'Random Forest'],
 'explained variance score': ['0.664320011',
  '0.744387315',
  '0.714108384',
  '0.725741767'],
 'mae score': ['0.509707', '0.322739', '0.346004', '0.320631'],
 'mse score': ['0.447138', '0.299437', '0.333122', '0.319691'],
 'r2 score': ['0.615889', '0.742771', '0.713833', '0.725371'],
 'mean fit time': [0.06111502647399902,
  0.09474420547485352,
  0.20879764556884767,
  0.22972640991210938]}
)

# %%
ma_boosting_df
# Out:
#                     model explained variance score mae score mse score  \
# 0               Ada Boost              0.664320011  0.509707  0.447138
# 1       Gradient Boosting              0.744387315  0.322739  0.299437
# 2  Hist Gradient Boosting              0.714108384  0.346004  0.333122
# 3           Random Forest              0.725741767  0.320631  0.319691
#
#    r2 score  mean fit time
# 0  0.615889       0.061115
# 1  0.742771       0.094744
# 2  0.713833       0.208798
# 3  0.725371       0.229726

# %% [markdown]
# ####  Just like the values for other states, for Massachusettes the State level Gradient Boosting provided a slightly better R2 score.
